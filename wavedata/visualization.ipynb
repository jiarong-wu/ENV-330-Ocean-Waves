# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import matplotlib.dates as mdates

import xarray as xr

# %%
# The one with single variables
# ds = xr.load_dataset('./WW3-GLOB-30M_201101_pdir0.nc')
# The one where all the variables are together
ds = xr.load_dataset('LOPS_WW3-GLOB-30M_202201.nc')

# %%
phs0_2d = ds2.phs0.isel(time=100)
phs1_2d = ds2.phs1.isel(time=100)
phs2_2d = ds2.phs2.isel(time=100)

# %%
import cartopy.crs as ccrs
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, subplot_kw={'projection': ccrs.LambertCylindrical(), 'facecolor': 'gray'}, figsize=[20,15])

phs0_2d = ds2.phs0.isel(time=100) # Wind wave wave height
p0 = phs0_2d.plot(
     transform=ccrs.PlateCarree(), ax=ax1
)
p0.axes.set_global()
p0.axes.coastlines()

phs1_2d = ds2.phs1.isel(time=100) # Swell system 1 wave height
p1 = phs1_2d.plot(
     transform=ccrs.PlateCarree(), ax=ax2
)
p1.axes.set_global()
p1.axes.coastlines()

phs2_2d = ds2.phs2.isel(time=100) # Swell system 2 wave height
p2 = phs2_2d.plot(
     transform=ccrs.PlateCarree(), ax=ax3
)
p2.axes.set_global()
p2.axes.coastlines()

phs3_2d = ds2.phs3.isel(time=100) # Swell system 3 wave height
p3 = phs3_2d.plot(
     transform=ccrs.PlateCarree(), ax=ax4
)
p3.axes.set_global()
p3.axes.coastlines()

# %%
import cartopy.crs as ccrs
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, subplot_kw={'projection': ccrs.LambertCylindrical(), 'facecolor': 'gray'}, figsize=[20,15])

phs0_2d = ds2.phs0.isel(time=100) # Wind wave wave height
p0 = phs0_2d.plot(
     transform=ccrs.PlateCarree(), ax=ax1
)
p0.axes.set_global()
p0.axes.coastlines()

uwnd_2d = ds2.uwnd.isel(time=100) # U component of wind
p1 = uwnd_2d.plot(
     transform=ccrs.PlateCarree(), ax=ax3
)
p1.axes.set_global()
p1.axes.coastlines()

ucur_2d = ds2.ucur.isel(time=100) # U component of current
p2 = ucur_2d.plot(
     transform=ccrs.PlateCarree(), ax=ax4
)
p2.axes.set_global()
p2.axes.coastlines()

phs1_2d = ds2.phs1.isel(time=100) # Swell wave height
p3 = phs1_2d.plot(
     transform=ccrs.PlateCarree(), ax=ax2
)
p3.axes.set_global()
p3.axes.coastlines()
